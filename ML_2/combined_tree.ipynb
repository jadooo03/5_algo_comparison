# %% [markdown]
# Import Statements

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import random 
from pprint import pprint

# %% [markdown]
# Load and Prepare Data

# %%
def determine_type_of_feature(df):
    feature_types = []
    n_unique_values_threshold = 15

    for column in df.columns:
        unique_values = df[column].unique()
        example_value = unique_values[0]

        if (isinstance(example_value, str)) or (len(unique_values) <= n_unique_values_threshold):
            feature_types.append("Discrete")
        else:
            feature_types.append("Continuous")
    
    return feature_types

# %%
global FEATURE_TYPES
df = pd.read_csv('census-income.data.csv')
FEATURE_TYPES = determine_type_of_feature(df)

# %%
#Checking which all columns have missing values
def missing_values(df):
    c=0
    for i in df.columns:
        x,count_missing = np.unique(df[i].eq('?'),return_counts=True)
        if len(x)==2:
            print(i,"-",FEATURE_TYPES[c],"-",count_missing[1])
        # elif len(x)==1 and x[0] == False:
        #     print(i,"-",FEATURE_TYPES[c],"- 0",)
        c+=1

# %% [markdown]
# Random Splitting Of Data

# %%
def train_test_split(df,test_size):
    #checks whether the test_size is a proportion of the total number of samples
    if isinstance(test_size,float): 
        test_size = round(test_size*len(df))

    #store random samples in the test and training data
    indices = df.index.tolist()
    test_indices = random.sample(population=indices, k = test_size)

    #random data points from sample sent to test and training data
    test_df = df.loc[test_indices]
    train_df = df.drop(test_indices)

    return train_df , test_df

# %% [markdown]
# Data Pure?

# %%
def check_purity(data):
    label_column = data[:,-1]
    unique_classes = np.unique(label_column)

    if len(unique_classes) ==  1:
        return True    
    else:
        return False

# %% [markdown]
# Classify Data

# %%
def classify_data(data): 
    label_column = data[:,-1]
    unique_classes , counts_unique_classes = np.unique(label_column,return_counts = True)

    index = counts_unique_classes.argmax()
    classification = unique_classes[index]
    return classification

# %%
def get_potential_splits(data):
    potential_splits = {}
    rows , n_columns = data.shape

    for column_index in range(n_columns-1):
        values = data[:,column_index]
        unique_values = np.unique(values)
        
        
        potential_splits[column_index] = unique_values
            
    return potential_splits

# %%
# potential_splits = get_potential_splits(train_df.values)

# sns.lmplot(data = train_df, x = "petal_width", y = "petal_length",hue = "label", fit_reg = False,height=6,aspect = 1.5)

# # plt.vlines(x = potential_splits[3], ymin = 1, ymax =7)
# # plt.hlines(y=potential_splits[2],xmin=0,xmax =2.5)

# %% [markdown]
# Split Data

# %%
def split_data(data, split_column,split_value):
    split_column_values = data[:,split_column]

    type_of_feature = FEATURE_TYPES[split_column]
    
    if type_of_feature == "Continuous":
        data_below = data[split_column_values <= split_value]
        data_above = data[split_column_values > split_value]
    
    else:
        data_below = data[split_column_values == split_value]
        data_above = data[split_column_values != split_value]

    return data_below , data_above

# %%
# split_value = 0.8
# plotting_df = pd.DataFrame(data,columns = df.columns)
# sns.lmplot(data = plotting_df, x = "petal_width", y = "petal_length", fit_reg=False)
# plt.vlines(x = split_value,ymin = 1, ymax =7)

# %%
def calculate_entropy(data):
    label_column = data[:,-1]
    rows , counts = np.unique(label_column , return_counts =True)

    probabilities = counts / counts.sum()
    entropy = np.sum(probabilities*-np.log2(probabilities))

    return entropy

# %%
def calculate_overall_entropy(data_below, data_above):
    
    n_data_points = len(data_below) + len(data_above)

    p_data_below = len(data_below) / n_data_points
    p_data_above = len(data_above) / n_data_points

    overall_entropy = (p_data_below*calculate_entropy(data_below) + p_data_above*calculate_entropy(data_above))

    return overall_entropy

# %%
def determine_best_splits(data, potential_splits):

    overall_entropy = 999
    
    for column_index in potential_splits:
        # print(COLUMN_HEADERS[column_index],"-",len(np.unique(data[:, column_index])))
        for value in potential_splits[column_index]:
            
            data_below, data_above = split_data(data,split_column = column_index,split_value = value)
            current_overall_entropy = calculate_overall_entropy(data_below, data_above)
            
            if current_overall_entropy <= overall_entropy:
                overall_entropy = current_overall_entropy
                best_split_column = column_index
                best_split_value = value
    
    return best_split_column, best_split_value

# %% [markdown]
# Determine Whether Column is Discrete or Continuous

# %%
def decision_tree_algorithm(df , counter =0, min_samples=5, max_depth = 5):
    # print(counter)
    #Data Preparation
    if counter == 0:
        global COLUMN_HEADERS 
        global FEATURE_TYPES 
        COLUMN_HEADERS = df.columns
        FEATURE_TYPES = determine_type_of_feature(df)
        data = df.values
    else:
        data = df

    #Base Case 
    if (check_purity(data)) or (len(data) < min_samples) or (counter == max_depth):
        classification = classify_data(data)
        return classification 
    
    #Recursive case
    else:
        counter = counter + 1
        
        #helper functions
        potential_splits = get_potential_splits(data)        
        split_column,split_value = determine_best_splits(data,potential_splits)
        data_below,data_above = split_data(data,split_column,split_value)

        #checking for empty data

        if len(data_below) == 0 or len(data_above) == 0:
            classification = classify_data(data)
            return classification

        #instantiating the sub-trees
        feature_name = COLUMN_HEADERS[split_column]
        type_of_feature = FEATURE_TYPES[split_column]
        if type_of_feature == "Continuous":
            question = "{} <= {}".format(feature_name,split_value)

        else:
            question = "{} = {}".format(feature_name,split_value)

        sub_tree = {question:[]}

        #find answers (here recursion is used)
        yes_answer = decision_tree_algorithm(data_below, counter, min_samples , max_depth)
        no_answer = decision_tree_algorithm(data_above, counter, min_samples , max_depth)

        if yes_answer == no_answer:
            sub_tree = yes_answer
        else:
            sub_tree[question].append(yes_answer)
            sub_tree[question].append(no_answer)

        return sub_tree

# %%
def classify_example(example,tree):
    question = list(tree.keys())[0]
    feature_name , comparison_operator, value = question.split()

    #Asking the question to the example
    if comparison_operator == "<=":

        if example[feature_name] <= float(value):
            answer = tree[question][0]
        else:
            answer = tree[question][1]

    else:
        if str(example[feature_name]) == value:
            answer = tree[question][0]
        else:
            answer = tree[question][1]
    #base Case
    if not isinstance(answer,dict):
        return answer

    #recursive part
    else:
        remaining_tree = answer
        return classify_example(example,remaining_tree)

# %%
def calculate_accuracy(df,tree):

    df["Classification"] = df.apply(classify_example,axis=1,args = (tree,))
    df["Classification_Correct"] = df.Classification == df.label

    accuracy = df.Classification_Correct.mean()

    return accuracy

# %%
def make_predictions(df, tree):
    
    if len(df) != 0:
        predictions = df.apply(classify_example, args=(tree,), axis=1)
    else:
        # "df.apply()"" with empty dataframe returns an empty dataframe,
        # but "predictions" should be a series instead
        predictions = pd.Series()
        
    return predictions

# %%
def filter_df(df,question):
    feature,comparison_operator,value = question.split()

    if (comparison_operator) == "<=":
        df_yes = df[df[feature]<= float(value)]
        df_no = df[df[feature] > float(value)]
    
    else:
        df_yes = df[df[feature].astype(str) == value]
        df_no = df[df[feature].astype(str) != value]
        

    return df_yes,df_no

# %%
def pruning_result(tree, df_train, df_val):
    leaf = df_train.label.value_counts().index[0]
    errors_leaf = sum(df_val.label != leaf) #here we can find the accuracy also :D
    errors_decision_node = sum(df_val.label != make_predictions(df_val,tree))

    if errors_leaf <= errors_decision_node:
            return leaf
    else:
            return tree

# %%
def post_pruning(tree , df_train , df_val):
    question = list(tree.keys())[0]
    yes_answer , no_answer = tree[question]

    #base case
    if not isinstance(yes_answer,dict) and not isinstance(no_answer,dict):
        return pruning_result(tree , df_train , df_val)
    
    else: #Recursive case
        df_train_yes, df_train_no = filter_df(df_train , question)
        df_val_yes, df_val_no = filter_df(df_val , question)

        if isinstance(yes_answer,dict):
            yes_answer = post_pruning(yes_answer,df_train_yes,df_val_yes)

        if isinstance(no_answer,dict):
            no_answer = post_pruning(no_answer,df_train_no,df_val_no)
    
    tree = {question : [yes_answer,no_answer]}

    return pruning_result(tree , df_train , df_val)

# %%
def count_nodes(tree):
    if isinstance(tree, dict):
        count = 1  # Start with 1 for the current node
        for value in tree.values():
            count += count_nodes(value)  # Recursively count nodes in child dictionaries
        return count
    elif isinstance(tree, list):
        count = 0
        for node in tree:
            count += count_nodes(node)  # Recursively count nodes in child dictionaries
        return count
    else:
        return 1  # Reached a leaf node

# %%
def count_depth(tree):
    if isinstance(tree, dict):
        if not tree:  # Base case: empty dictionary
            return 1
        else:
            return 1 + max(count_depth(value) for value in tree.values())
    elif isinstance(tree, list):
        if not tree:  # Base case: empty list
            return 1
        else:
            return 1 + max(count_depth(item) for item in tree)
    else:
        return 0  # Base case: leaf node or invalid input

# %%
df1 = pd.read_csv("census-income.data.csv")
df2 = pd.read_csv("census-income.test.csv")

# %%
df2['label'] = df2['label'].str.replace('.', '')

# %%
missing_values(df1)
# Out:
# workclass - Discrete - 1836
# occupation - Discrete - 1843
# native_countr - Discrete - 583

# %%
def fill_values(df):
    #Since all columns are having the discrete value. We replace it with the missing values with the modes, i.e. the highest appearing value
    mode_workclass = df.workclass.mode()[0]
    mode_occupation = df.occupation.mode()[0]
    mode_native_countr = df.native_countr.mode()[0]

    #Filling the train and test data with the modes of missing values as they are discrete
    df.workclass = df.workclass.replace('?', mode_workclass)
    df.occupation = df.occupation.replace('?', mode_occupation)
    df.native_countr = df.native_countr.replace('?', mode_native_countr)
    missing_values(df)#No missing values
    return df

# %%
df1 = fill_values(df1)
df2 = fill_values(df2)

# %%
df_combined = pd.concat([df1,df2],ignore_index=True)

# %%
missing_values(df_combined)

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       48842 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education_num   48842 non-null  int64
#  5   marital_status  48842 non-null  object
#  6   occupation      48842 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital_gain    48842 non-null  int64
#  11  capital_loss    48842 non-null  int64
#  12  hours_per_week  48842 non-null  int64
#  13  native_countr   48842 non-null  object
#  14  label           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df_train , df_test = train_test_split(df_combined , 0.33 )

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32724 entries, 2 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32724 non-null  int64
#  1   workclass       32724 non-null  object
#  2   fnlwgt          32724 non-null  int64
#  3   education       32724 non-null  object
#  4   education_num   32724 non-null  int64
#  5   marital_status  32724 non-null  object
#  6   occupation      32724 non-null  object
#  7   relationship    32724 non-null  object
#  8   race            32724 non-null  object
#  9   sex             32724 non-null  object
#  10  capital_gain    32724 non-null  int64
#  11  capital_loss    32724 non-null  int64
#  12  hours_per_week  32724 non-null  int64
#  13  native_countr   32724 non-null  object
#  14  label           32724 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 4.0+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16118 entries, 14905 to 1323
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             16118 non-null  int64
#  1   workclass       16118 non-null  object
#  2   fnlwgt          16118 non-null  int64
#  3   education       16118 non-null  object
#  4   education_num   16118 non-null  int64
#  5   marital_status  16118 non-null  object
#  6   occupation      16118 non-null  object
#  7   relationship    16118 non-null  object
#  8   race            16118 non-null  object
#  9   sex             16118 non-null  object
#  10  capital_gain    16118 non-null  int64
#  11  capital_loss    16118 non-null  int64
#  12  hours_per_week  16118 non-null  int64
#  13  native_countr   16118 non-null  object
#  14  label           16118 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 2.0+ MB

# %%
tree_combined = decision_tree_algorithm(df_train,max_depth = 10000000)

# %%
tree = tree_combined

# %%
tree
# Out:
# {'marital_status = Married-civ-spouse': [{'capital_gain <= 5013': [{'education_num <= 11': [{'education_num <= 8': [{'age <= 37': [{'hours_per_week <= 49': [{'native_countr = Trinadad&Tobago': ['>50K',
#               {'race = Asian-Pac-Islander': [{'fnlwgt <= 102986': ['>50K',
#                   '<=50K']},
#                 {'relationship = Husband': [{'education = 9th': ['<=50K',
#                     {'occupation = Tech-support': ['<=50K',
#                       {'workclass = Self-emp-not-inc': ['<=50K',
#                         {'education_num <= 7': [{'occupation = Adm-clerical': ['<=50K',
#                             {'age <= 31': ['<=50K',
#                               {'age <= 32': [{'race = White': ['<=50K',
#                                   '>50K']},
#                                 {'fnlwgt <= 112271': [{'fnlwgt <= 89040': ['<=50K',
#                                     {'education = 10th': ['<=50K', '>50K']}]},
#                                   '<=50K']}]}]}]},
#                           {'age <= 32': [{'occupation = Sales': ['>50K',
#                               {'fnlwgt <= 162687': [{'fnlwgt <= 123291': ['<=50K',
#                                   '>50K']},
#                                 '<=50K']}]},
#                             '<=50K']}]}]}]}]},
#                   '<=50K']}]}]},
#             {'education_num <= 4': ['<=50K',
#               {'native_countr = Portugal': ['>50K',
#                 {'hours_per_week <= 65': [{'relationship = Not-in-family': ['>50K',
#                     {'workclass = Self-emp-inc': ['>50K',
#                       {'education_num <= 5': [{'fnlwgt <= 147258': ['>50K',
#                           '<=50K']},
#                         '<=50K']}]}]},
#                   {'occupation = Farming-fishing': ['<=50K',
#                     {'age <= 32': ['>50K',
#                       {'education_num <= 5': ['>50K', '<=50K']}]}]}]}]}]}]},
#           {'hours_per_week <= 29': [{'capital_loss <= 2179': [{'education_num <= 4': ['<=50K',
#                 {'fnlwgt <= 266019': [{'race = Black': [{'education_num <= 6': ['<=50K',
#                       '>50K']},
#                     '<=50K']},
#                   '<=50K']}]},
#               '>50K']},
#             {'capital_loss <= 1740': [{'occupation = Exec-managerial': [{'workclass = Self-emp-inc': ['<=50K',
#                   {'fnlwgt <= 190997': [{'education = 10th': ['<=50K',
#                       {'hours_per_week <= 47': ['<=50K',
#                         {'education_num <= 4': ['>50K', '<=50K']}]}]},
#                     {'age <= 48': ['>50K',
#                       {'fnlwgt <= 268234': ['<=50K', '>50K']}]}]}]},
#                 {'education_num <= 5': [{'fnlwgt <= 163948': [{'hours_per_week <= 49': [{'education = 5th-6th': [{'age <= 56': [{'age <= 53': [{'native_countr = Vietnam': ['>50K',
#                               {'age <= 44': ['<=50K',
#                                 {'age <= 46': ['>50K',
#                                   {'hours_per_week <= 40': ['<=50K',
#                                     '>50K']}]}]}]},
#                             '>50K']},
#                           {'hours_per_week <= 30': ['>50K', '<=50K']}]},
#                         {'fnlwgt <= 34297': [{'hours_per_week <= 30': ['>50K',
#                             {'fnlwgt <= 30270': ['<=50K',
#                               {'fnlwgt <= 30673': ['>50K',
#                                 {'fnlwgt <= 31964': ['<=50K', '>50K']}]}]}]},
#                           {'fnlwgt <= 104945': ['<=50K',
#                             {'fnlwgt <= 105592': ['>50K',
#                               {'fnlwgt <= 124090': ['<=50K',
#                                 {'fnlwgt <= 125417': ['>50K',
#                                   {'age <= 71': ['<=50K', '>50K']}]}]}]}]}]}]},
#                       {'native_countr = United-States': [{'fnlwgt <= 33186': ['<=50K',
#                           {'fnlwgt <= 35723': ['>50K',
#                             {'capital_gain <= 2580': [{'occupation = Farming-fishing': ['>50K',
#                                 {'age <= 58': ['<=50K',
#                                   {'hours_per_week <= 60': [{'education = 7th-8th': ['<=50K',
#                                       '>50K']},
#                                     '<=50K']}]}]},
#                               '>50K']}]}]},
#                         '>50K']}]},
#                     {'occupation = Other-service': ['<=50K',
#                       {'fnlwgt <= 175262': ['<=50K',
#                         {'fnlwgt <= 175847': ['>50K',
#                           {'education_num <= 3': [{'fnlwgt <= 237321': [{'fnlwgt <= 230020': ['<=50K',
#                                 '>50K']},
#                               '<=50K']},
#                             {'occupation = Prof-specialty': ['<=50K',
#                               {'hours_per_week <= 55': [{'age <= 63': [{'age <= 58': [{'age <= 56': [{'age <= 52': [{'fnlwgt <= 184787': ['>50K',
#                                           {'fnlwgt <= 252392': ['<=50K',
#                                             {'hours_per_week <= 35': ['>50K',
#                                               {'fnlwgt <= 254230': ['>50K',
#                                                 {'occupation = Machine-op-inspct': ['<=50K',
#                                                   {'fnlwgt <= 414448': ['<=50K',
#                                                     {'fnlwgt <= 425502': ['>50K',
#                                                       '<=50K']}]}]}]}]}]}]},
#                                         '<=50K']},
#                                       {'fnlwgt <= 214502': ['>50K',
#                                         '<=50K']}]},
#                                     '<=50K']},
#                                   {'fnlwgt <= 325373': [{'native_countr = United-States': ['<=50K',
#                                       '>50K']},
#                                     '>50K']}]},
#                                 '<=50K']}]}]}]}]}]}]},
#                   {'age <= 66': [{'fnlwgt <= 368005': [{'age <= 43': [{'native_countr = Cuba': ['>50K',
#                           {'capital_gain <= 2635': [{'age <= 40': ['<=50K',
#                               {'age <= 41': [{'occupation = Handlers-cleaners': ['>50K',
#                                   '<=50K']},
#                                 '<=50K']}]},
#                             '>50K']}]},
#                         {'occupation = Sales': [{'native_countr = United-States': [{'education_num <= 6': ['<=50K',
#                               {'hours_per_week <= 30': ['>50K',
#                                 {'fnlwgt <= 106061': ['<=50K',
#                                   {'sex = Male': ['>50K', '<=50K']}]}]}]},
#                             '>50K']},
#                           {'fnlwgt <= 127149': [{'age <= 61': [{'age <= 45': ['<=50K',
#                                 {'occupation = Craft-repair': [{'fnlwgt <= 97168': ['>50K',
#                                     {'fnlwgt <= 104272': ['<=50K',
#                                       {'hours_per_week <= 40': ['<=50K',
#                                         '>50K']}]}]},
#                                   {'occupation = Transport-moving': [{'age <= 56': [{'age <= 49': ['>50K',
#                                         '<=50K']},
#                                       {'fnlwgt <= 88055': ['<=50K', '>50K']}]},
#                                     {'education_num <= 7': [{'age <= 46': ['>50K',
#                                         {'fnlwgt <= 112860': [{'age <= 60': ['<=50K',
#                                             '>50K']},
#                                           '<=50K']}]},
#                                       '>50K']}]}]}]},
#                               '<=50K']},
#                             {'occupation = Tech-support': ['>50K',
#                               {'fnlwgt <= 249043': [{'fnlwgt <= 240988': [{'race = White': [{'workclass = Private': [{'age <= 52': [{'hours_per_week <= 30': ['>50K',
#                                           {'capital_loss <= 0': [{'age <= 45': ['>50K',
#                                               {'hours_per_week <= 38': ['<=50K',
#                                                 {'fnlwgt <= 232132': [{'fnlwgt <= 207848': [{'age <= 50': [{'hours_per_week <= 40': [{'age <= 47': ['<=50K',
#                                                           {'occupation = Craft-repair': ['>50K',
#                                                             '<=50K']}]},
#                                                         {'fnlwgt <= 185291': ['>50K',
#                                                           '<=50K']}]},
#                                                       '<=50K']},
#                                                     '>50K']},
#                                                   '<=50K']}]}]},
#                                             '>50K']}]},
#                                         {'education_num <= 6': [{'fnlwgt <= 152731': ['<=50K',
#                                             {'fnlwgt <= 173866': ['>50K',
#                                               {'native_countr = Cuba': ['>50K',
#                                                 {'fnlwgt <= 200217': [{'fnlwgt <= 199085': ['<=50K',
#                                                     '>50K']},
#                                                   '<=50K']}]}]}]},
#                                           '<=50K']}]},
#                                       '<=50K']},
#                                     '<=50K']},
#                                   {'race = White': ['<=50K', '>50K']}]},
#                                 {'age <= 44': [{'race = White': ['<=50K',
#                                     '>50K']},
#                                   '<=50K']}]}]}]}]}]},
#                       {'fnlwgt <= 455379': [{'race = White': [{'education_num <= 7': [{'fnlwgt <= 379350': ['<=50K',
#                               '>50K']},
#                             {'workclass = Private': ['<=50K', '>50K']}]},
#                           '<=50K']},
#                         '<=50K']}]},
#                     '<=50K']}]}]},
#               {'capital_loss <= 1977': [{'education_num <= 5': [{'capital_loss <= 1887': ['>50K',
#                     '<=50K']},
#                   '>50K']},
#                 '<=50K']}]}]}]},
#         {'age <= 35': [{'age <= 24': [{'hours_per_week <= 47': [{'fnlwgt <= 216853': [{'capital_gain <= 3781': [{'fnlwgt <= 65481': [{'fnlwgt <= 62278': [{'workclass = Self-emp-not-inc': ['>50K',
#                         '<=50K']},
#                       '>50K']},
#                     '<=50K']},
#                   '<=50K']},
#                 {'capital_loss <= 1573': [{'fnlwgt <= 515797': [{'hours_per_week <= 42': [{'age <= 22': ['<=50K',
#                         {'fnlwgt <= 236696': ['<=50K',
#                           {'fnlwgt <= 237341': ['>50K',
#                             {'fnlwgt <= 316841': ['<=50K',
#                               {'fnlwgt <= 325179': ['>50K', '<=50K']}]}]}]}]},
#                       {'occupation = Other-service': ['>50K',
#                         {'occupation = Adm-clerical': ['>50K', '<=50K']}]}]},
#                     '<=50K']},
#                   '>50K']}]},
#               {'occupation = Transport-moving': [{'hours_per_week <= 49': ['>50K',
#                   {'fnlwgt <= 243923': [{'education_num <= 9': ['<=50K',
#                       '>50K']},
#                     '>50K']}]},
#                 {'age <= 23': ['<=50K',
#                   {'native_countr = United-States': [{'education_num <= 9': ['<=50K',
#                       {'occupation = Craft-repair': ['<=50K',
#                         {'fnlwgt <= 252024': ['>50K', '<=50K']}]}]},
#                     '>50K']}]}]}]},
#             {'capital_loss <= 1740': [{'education_num <= 9': [{'hours_per_week <= 37': [{'fnlwgt <= 262439': [{'fnlwgt <= 255647': [{'fnlwgt <= 90547': ['<=50K',
#                         {'fnlwgt <= 98168': ['>50K',
#                           {'age <= 33': ['<=50K',
#                             {'relationship = Wife': [{'fnlwgt <= 203814': ['<=50K',
#                                 '>50K']},
#                               '<=50K']}]}]}]},
#                       '>50K']},
#                     '<=50K']},
#                   {'occupation = Exec-managerial': [{'workclass = Self-emp-not-inc': ['<=50K',
#                       {'age <= 34': [{'fnlwgt <= 39054': ['>50K',
#                           {'native_countr = Canada': ['>50K',
#                             {'fnlwgt <= 80557': ['<=50K',
#                               {'age <= 30': [{'fnlwgt <= 167336': [{'hours_per_week <= 50': [{'fnlwgt <= 161444': ['<=50K',
#                                       '>50K']},
#                                     '>50K']},
#                                   {'fnlwgt <= 244408': ['<=50K',
#                                     {'fnlwgt <= 271466': ['>50K',
#                                       '<=50K']}]}]},
#                                 {'hours_per_week <= 45': [{'age <= 31': ['>50K',
#                                     {'native_countr = United-States': [{'sex = Male': [{'fnlwgt <= 201874': [{'fnlwgt <= 183778': ['>50K',
#                                             '<=50K']},
#                                           '>50K']},
#                                         '<=50K']},
#                                       '<=50K']}]},
#                                   {'native_countr = United-States': ['<=50K',
#                                     '>50K']}]}]}]}]}]},
#                         {'hours_per_week <= 60': [{'fnlwgt <= 128516': [{'fnlwgt <= 122353': [{'fnlwgt <= 31269': ['<=50K',
#                                 '>50K']},
#                               '<=50K']},
#                             '>50K']},
#                           '<=50K']}]}]},
#                     {'occupation = Protective-serv': [{'fnlwgt <= 319280': [{'fnlwgt <= 216035': [{'race = Asian-Pac-Islander': ['>50K',
#                             {'age <= 29': ['<=50K',
#                               {'age <= 31': ['>50K',
#                                 {'age <= 33': ['<=50K',
#                                   {'fnlwgt <= 177974': ['>50K',
#                                     '<=50K']}]}]}]}]},
#                           '>50K']},
#                         '<=50K']},
#                       {'hours_per_week <= 45': [{'relationship = Wife': [{'workclass = Federal-gov': ['>50K',
#                             {'age <= 32': [{'capital_gain <= 3464': [{'race = White': [{'hours_per_week <= 40': [{'fnlwgt <= 185480': [{'fnlwgt <= 91501': [{'occupation = Adm-clerical': ['>50K',
#                                           '<=50K']},
#                                         {'occupation = Machine-op-inspct': ['<=50K',
#                                           '>50K']}]},
#                                       {'age <= 28': ['<=50K',
#                                         {'fnlwgt <= 256671': ['<=50K',
#                                           '>50K']}]}]},
#                                     '<=50K']},
#                                   '<=50K']},
#                                 '>50K']},
#                               {'fnlwgt <= 403468': ['<=50K', '>50K']}]}]},
#                           {'occupation = Farming-fishing': ['<=50K',
#                             {'race = White': [{'fnlwgt <= 39232': ['<=50K',
#                                 {'native_countr = Yugoslavia': ['>50K',
#                                   {'occupation = Other-service': [{'fnlwgt <= 236861': ['<=50K',
#                                       {'fnlwgt <= 244147': ['>50K',
#                                         '<=50K']}]},
#                                     {'native_countr = Cuba': ['>50K',
#                                       {'fnlwgt <= 39257': ['>50K',
#                                         {'age <= 26': [{'fnlwgt <= 210521': [{'fnlwgt <= 198801': ['<=50K',
#                                               '>50K']},
#                                             '<=50K']},
#                                           {'age <= 34': [{'capital_loss <= 0': [{'occupation = Handlers-cleaners': [{'fnlwgt <= 125762': ['<=50K',
#                                                   {'fnlwgt <= 174201': [{'age <= 32': [{'hours_per_week <= 38': ['>50K',
#                                                         {'fnlwgt <= 161599': ['>50K',
#                                                           '<=50K']}]},
#                                                       '<=50K']},
#                                                     {'fnlwgt <= 205152': ['<=50K',
#                                                       {'fnlwgt <= 206051': ['>50K',
#                                                         '<=50K']}]}]}]},
#                                                 {'occupation = Adm-clerical': [{'capital_gain <= 3464': [{'workclass = Federal-gov': ['>50K',
#                                                       '<=50K']},
#                                                     '>50K']},
#                                                   {'hours_per_week <= 38': ['>50K',
#                                                     {'relationship = Husband': [{'fnlwgt <= 55390': [{'age <= 32': ['<=50K',
#                                                           '>50K']},
#                                                         {'fnlwgt <= 78261': ['<=50K',
#                                                           {'fnlwgt <= 79661': ['>50K',
#                                                             {'capital_gain <= 3103': [{'capital_gain <= 2829': [{'capital_gain <= 0': [{'fnlwgt <= 92262': [{'age <= 27': ['>50K',
#                                                                       '<=50K']},
#                                                                     {'fnlwgt <= 94413': ['>50K',
#                                                                       {'fnlwgt <= 103435': ['<=50K',
#                                                                         {'fnlwgt <= 103642': ['>50K',
#                                                                           {'occupation = Transport-moving': [{'hours_per_week <= 40': [{'workclass = State-gov': ['>50K',
#                                                                                 '<=50K']},
#                                                                               {'age <= 31': ['>50K',
#                                                                                 '<=50K']}]},
#                                                                             {'age <= 33': [{'workclass = Self-emp-not-inc': [{'fnlwgt <= 108438': ['>50K',
#                                                                                   {'fnlwgt <= 184710': ['<=50K',
#                                                                                     {'fnlwgt <= 204052': ['>50K',
#                                                                                       '<=50K']}]}]},
#                                                                                 {'occupation = Prof-specialty': [{'age <= 29': ['>50K',
#                                                                                     '<=50K']},
#                                                                                   {'fnlwgt <= 111567': ['<=50K',
#                                                                                     {'fnlwgt <= 112941': ['>50K',
#                                                                                       {'fnlwgt <= 114691': ['<=50K',
#                                                                                         {'fnlwgt <= 122116': ['<=50K',
#                                                                                           {'fnlwgt <= 125762': ['>50K',
#                                                                                             {'fnlwgt <= 196266': [{'fnlwgt <= 195770': [{'fnlwgt <= 190511': [{'fnlwgt <= 173851': [{'workclass = Private': [{'age <= 31': [{'hours_per_week <= 43': [{'fnlwgt <= 160731': [{'fnlwgt <= 132874': ['<=50K',
#                                                                                                               {'fnlwgt <= 140206': ['>50K',
#                                                                                                                 {'occupation = Craft-repair': [{'native_countr = United-States': [{'fnlwgt <= 154227': ['>50K',
#                                                                                                                       '<=50K']},
#                                                                                                                     '>50K']},
#                                                                                                                   '<=50K']}]}]},
#                                                                                                             '<=50K']},
#                                                                                                           '<=50K']},
#                                                                                                         '<=50K']},
#                                                                                                       '>50K']},
#                                                                                                     {'fnlwgt <= 190303': [{'fnlwgt <= 173944': ['>50K',
#                                                                                                         {'age <= 27': ['<=50K',
#                                                                                                           {'fnlwgt <= 174789': ['<=50K',
#                                                                                                             {'fnlwgt <= 188246': [{'fnlwgt <= 184901': [{'fnlwgt <= 183801': [{'fnlwgt <= 183612': [{'hours_per_week <= 40': [{'occupation = Craft-repair': ['<=50K',
#                                                                                                                         {'fnlwgt <= 177727': ['>50K',
#                                                                                                                           {'age <= 29': ['<=50K',
#                                                                                                                             '>50K']}]}]},
#                                                                                                                       '>50K']},
#                                                                                                                     '<=50K']},
#                                                                                                                   '>50K']},
#                                                                                                                 '<=50K']},
#                                                                                                               '>50K']}]}]}]},
#                                                                                                       '>50K']}]},
#                                                                                                   '<=50K']},
#                                                                                                 '>50K']},
#                                                                                               {'fnlwgt <= 224849': [{'fnlwgt <= 207064': [{'fnlwgt <= 206051': ['<=50K',
#                                                                                                     '>50K']},
#                                                                                                   '<=50K']},
#                                                                                                 {'fnlwgt <= 226443': ['>50K',
#                                                                                                   {'hours_per_week <= 42': [{'native_countr = United-States': [{'hours_per_week <= 40': [{'fnlwgt <= 256362': [{'age <= 31': ['<=50K',
#                                                                                                             {'fnlwgt <= 226624': ['<=50K',
#                                                                                                               '>50K']}]},
#                                                                                                           {'fnlwgt <= 329425': ['<=50K',
#                                                                                                             {'fnlwgt <= 332379': ['>50K',
#                                                                                                               {'age <= 27': ['>50K',
#                                                                                                                 {'fnlwgt <= 336951': ['<=50K',
#                                                                                                                   {'fnlwgt <= 337953': ['>50K',
#                                                                                                                     {'age <= 29': ['<=50K',
#                                                                                                                       {'age <= 30': ['>50K',
#                                                                                                                         {'fnlwgt <= 349148': [{'fnlwgt <= 349028': ['<=50K',
#                                                                                                                             '>50K']},
#                                                                                                                           '<=50K']}]}]}]}]}]}]}]}]},
#                                                                                                         '<=50K']},
#                                                                                                       '<=50K']},
#                                                                                                     {'occupation = Machine-op-inspct': ['<=50K',
#                                                                                                       {'fnlwgt <= 232954': ['<=50K',
#                                                                                                         '>50K']}]}]}]}]}]}]}]}]}]}]}]}]},
#                                                                               {'workclass = Self-emp-not-inc': ['>50K',
#                                                                                 {'occupation = Prof-specialty': ['<=50K',
#                                                                                   {'fnlwgt <= 305619': [{'fnlwgt <= 200117': [{'native_countr = United-States': [{'fnlwgt <= 115488': ['<=50K',
#                                                                                           {'fnlwgt <= 123270': ['>50K',
#                                                                                             {'hours_per_week <= 40': ['<=50K',
#                                                                                               '>50K']}]}]},
#                                                                                         '>50K']},
#                                                                                       '>50K']},
#                                                                                     '<=50K']}]}]}]}]}]}]}]}]},
#                                                                   '<=50K']},
#                                                                 '>50K']},
#                                                               '<=50K']}]}]}]},
#                                                       '<=50K']}]}]}]},
#                                               '<=50K']},
#                                             {'workclass = Private': [{'occupation = Handlers-cleaners': ['<=50K',
#                                                 {'occupation = Craft-repair': [{'fnlwgt <= 183279': ['<=50K',
#                                                     {'fnlwgt <= 186009': ['>50K',
#                                                       '<=50K']}]},
#                                                   '<=50K']}]},
#                                               {'fnlwgt <= 157473': ['<=50K',
#                                                 {'occupation = Craft-repair': [{'fnlwgt <= 184659': ['>50K',
#                                                     '<=50K']},
#                                                   '<=50K']}]}]}]}]}]}]}]}]}]},
#                               {'native_countr = Philippines': ['>50K',
#                                 {'fnlwgt <= 22201': ['>50K',
#                                   {'hours_per_week <= 38': ['<=50K',
#                                     {'fnlwgt <= 191957': [{'fnlwgt <= 190450': [{'occupation = Machine-op-inspct': ['<=50K',
#                                           {'age <= 33': ['<=50K',
#                                             {'race = Asian-Pac-Islander': ['>50K',
#                                               '<=50K']}]}]},
#                                         '>50K']},
#                                       '<=50K']}]}]}]}]}]}]},
#                         {'age <= 31': [{'race = Black': ['>50K',
#                             {'occupation = Adm-clerical': ['>50K',
#                               {'workclass = Local-gov': [{'fnlwgt <= 176992': ['>50K',
#                                   '<=50K']},
#                                 {'occupation = Farming-fishing': ['<=50K',
#                                   {'fnlwgt <= 111415': ['<=50K',
#                                     {'fnlwgt <= 115438': ['>50K',
#                                       {'relationship = Other-relative': ['>50K',
#                                         {'hours_per_week <= 48': ['<=50K',
#                                           {'capital_gain <= 3137': [{'fnlwgt <= 391114': [{'occupation = Prof-specialty': ['<=50K',
#                                                 {'hours_per_week <= 72': [{'age <= 30': [{'occupation = Craft-repair': ['<=50K',
#                                                       {'fnlwgt <= 266912': [{'fnlwgt <= 263728': [{'fnlwgt <= 219199': [{'fnlwgt <= 218781': [{'fnlwgt <= 185647': [{'fnlwgt <= 185127': ['<=50K',
#                                                                   '>50K']},
#                                                                 '<=50K']},
#                                                               '>50K']},
#                                                             '<=50K']},
#                                                           '>50K']},
#                                                         '<=50K']}]},
#                                                     {'fnlwgt <= 303851': [{'fnlwgt <= 213179': [{'hours_per_week <= 50': ['<=50K',
#                                                           '>50K']},
#                                                         '<=50K']},
#                                                       '>50K']}]},
#                                                   {'hours_per_week <= 80': ['>50K',
#                                                     '<=50K']}]}]},
#                                               '>50K']},
#                                             '>50K']}]}]}]}]}]}]}]}]},
#                           {'occupation = Other-service': ['<=50K',
#                             {'workclass = Self-emp-not-inc': [{'native_countr = United-States': ['<=50K',
#                                 '>50K']},
#                               {'hours_per_week <= 60': [{'age <= 32': [{'hours_per_week <= 46': ['>50K',
#                                     {'occupation = Tech-support': ['>50K',
#                                       {'occupation = Machine-op-inspct': ['>50K',
#                                         {'fnlwgt <= 171091': [{'fnlwgt <= 160458': [{'workclass = State-gov': ['>50K',
#                                               '<=50K']},
#                                             '>50K']},
#                                           '<=50K']}]}]}]},
#                                   {'race = White': [{'hours_per_week <= 46': ['<=50K',
#                                       {'fnlwgt <= 46492': ['>50K',
#                                         {'fnlwgt <= 54317': ['<=50K',
#                                           {'fnlwgt <= 107793': [{'occupation = Prof-specialty': ['<=50K',
#                                               '>50K']},
#                                             {'occupation = Transport-moving': [{'fnlwgt <= 121321': ['>50K',
#                                                 '<=50K']},
#                                               {'fnlwgt <= 122672': ['<=50K',
#                                                 {'fnlwgt <= 158438': [{'hours_per_week <= 48': ['<=50K',
#                                                     '>50K']},
#                                                   {'fnlwgt <= 174789': ['<=50K',
#                                                     {'fnlwgt <= 327902': [{'occupation = Machine-op-inspct': ['<=50K',
#                                                         {'fnlwgt <= 185084': ['>50K',
#                                                           {'occupation = Handlers-cleaners': ['<=50K',
#                                                             {'fnlwgt <= 195488': ['<=50K',
#                                                               {'capital_gain <= 0': [{'occupation = Prof-specialty': ['<=50K',
#                                                                   {'fnlwgt <= 214738': [{'fnlwgt <= 210310': [{'hours_per_week <= 50': ['<=50K',
#                                                                         '>50K']},
#                                                                       '<=50K']},
#                                                                     '>50K']}]},
#                                                                 '<=50K']}]}]}]}]},
#                                                       {'occupation = Craft-repair': ['<=50K',
#                                                         '>50K']}]}]}]}]}]}]}]}]}]},
#                                     '>50K']}]},
#                                 {'hours_per_week <= 78': [{'occupation = Sales': [{'workclass = Self-emp-inc': ['>50K',
#                                       '<=50K']},
#                                     '<=50K']},
#                                   '>50K']}]}]}]}]}]}]}]}]},
#                 {'fnlwgt <= 151053': [{'age <= 31': [{'workclass = Federal-gov': [{'occupation = Adm-clerical': ['>50K',
#                         '<=50K']},
#                       {'hours_per_week <= 35': ['<=50K',
#                         {'native_countr = Philippines': ['>50K',
#                           {'hours_per_week <= 36': ['>50K',
#                             {'workclass = Local-gov': [{'fnlwgt <= 98590': ['>50K',
#                                 '<=50K']},
#                               {'occupation = Farming-fishing': ['<=50K',
#                                 {'occupation = Sales': ['<=50K',
#                                   {'native_countr = Germany': ['>50K',
#                                     {'age <= 29': [{'fnlwgt <= 142712': [{'occupation = Exec-managerial': [{'fnlwgt <= 53434': [{'fnlwgt <= 39092': ['<=50K',
#                                               '>50K']},
#                                             '<=50K']},
#                                           {'age <= 27': [{'race = Amer-Indian-Eskimo': ['>50K',
#                                               '<=50K']},
#                                             '<=50K']}]},
#                                         '>50K']},
#                                       {'occupation = Transport-moving': ['>50K',
#                                         {'occupation = Exec-managerial': ['<=50K',
#                                           {'fnlwgt <= 34503': ['>50K',
#                                             {'occupation = Craft-repair': ['<=50K',
#                                               {'fnlwgt <= 73585': ['<=50K',
#                                                 {'fnlwgt <= 134615': [{'fnlwgt <= 106347': [{'occupation = Machine-op-inspct': ['>50K',
#                                                       '<=50K']},
#                                                     {'sex = Male': ['>50K',
#                                                       '<=50K']}]},
#                                                   '<=50K']}]}]}]}]}]}]}]}]}]}]}]}]}]}]},
#                     {'fnlwgt <= 27565': [{'occupation = Prof-specialty': ['<=50K',
#                         '>50K']},
#                       {'occupation = Other-service': ['<=50K',
#                         {'fnlwgt <= 33417': ['<=50K',
#                           {'fnlwgt <= 34080': ['>50K',
#                             {'fnlwgt <= 100446': [{'hours_per_week <= 48': ['<=50K',
#                                 {'occupation = Craft-repair': ['<=50K',
#                                   {'occupation = Farming-fishing': ['<=50K',
#                                     {'hours_per_week <= 55': [{'fnlwgt <= 38948': ['<=50K',
#                                         '>50K']},
#                                       '<=50K']}]}]}]},
#                               {'fnlwgt <= 103323': ['>50K',
#                                 {'occupation = Exec-managerial': [{'fnlwgt <= 115066': ['>50K',
#                                     '<=50K']},
#                                   {'occupation = Prof-specialty': [{'fnlwgt <= 139770': ['>50K',
#                                       '<=50K']},
#                                     {'native_countr = India': ['>50K',
#                                       {'hours_per_week <= 46': [{'fnlwgt <= 108837': [{'fnlwgt <= 103596': ['<=50K',
#                                             '>50K']},
#                                           {'fnlwgt <= 133839': [{'fnlwgt <= 131568': ['<=50K',
#                                               '>50K']},
#                                             '<=50K']}]},
#                                         {'fnlwgt <= 125279': [{'occupation = Tech-support': ['>50K',
#                                             '<=50K']},
#                                           {'age <= 33': ['>50K',
#                                             '<=50K']}]}]}]}]}]}]}]}]}]}]}]}]},
#                   {'capital_loss <= 1485': [{'age <= 29': [{'hours_per_week <= 25': ['<=50K',
#                         {'occupation = Farming-fishing': ['<=50K',
#                           {'capital_loss <= 0': [{'relationship = Wife': [{'age <= 25': ['>50K',
#                                 {'workclass = Private': [{'hours_per_week <= 42': [{'education_num <= 10': [{'age <= 26': ['<=50K',
#                                         {'fnlwgt <= 203558': ['>50K',
#                                           '<=50K']}]},
#                                       '<=50K']},
#                                     '<=50K']},
#                                   '>50K']}]},
#                               {'fnlwgt <= 155057': ['>50K',
#                                 {'fnlwgt <= 207473': [{'fnlwgt <= 200515': [{'fnlwgt <= 198258': [{'hours_per_week <= 65': [{'occupation = Transport-moving': ['<=50K',
#                                           {'fnlwgt <= 173992': [{'occupation = Adm-clerical': ['>50K',
#                                               {'fnlwgt <= 169683': ['<=50K',
#                                                 '>50K']}]},
#                                             '<=50K']}]},
#                                         '>50K']},
#                                       {'education_num <= 10': ['<=50K',
#                                         '>50K']}]},
#                                     '<=50K']},
#                                   {'occupation = Protective-serv': ['<=50K',
#                                     {'native_countr = Mexico': ['<=50K',
#                                       {'hours_per_week <= 60': [{'hours_per_week <= 38': ['<=50K',
#                                           {'capital_gain <= 2885': [{'capital_gain <= 0': [{'education_num <= 10': [{'fnlwgt <= 490332': [{'occupation = Craft-repair': [{'fnlwgt <= 238964': [{'fnlwgt <= 213842': ['<=50K',
#                                                         '>50K']},
#                                                       '<=50K']},
#                                                     {'native_countr = United-States': [{'race = White': [{'age <= 26': [{'occupation = Adm-clerical': ['>50K',
#                                                             {'workclass = Self-emp-inc': ['>50K',
#                                                               '<=50K']}]},
#                                                           {'workclass = Private': [{'age <= 28': [{'hours_per_week <= 40': [{'fnlwgt <= 228075': ['<=50K',
#                                                                   '>50K']},
#                                                                 '<=50K']},
#                                                               '>50K']},
#                                                             '<=50K']}]},
#                                                         {'fnlwgt <= 212232': ['>50K',
#                                                           '<=50K']}]},
#                                                       '>50K']}]},
#                                                   '<=50K']},
#                                                 {'fnlwgt <= 250967': [{'fnlwgt <= 209085': ['>50K',
#                                                     '<=50K']},
#                                                   {'occupation = Other-service': ['<=50K',
#                                                     '>50K']}]}]},
#                                               '<=50K']},
#                                             '>50K']}]},
#                                         '<=50K']}]}]}]}]}]},
#                             '>50K']}]}]},
#                       {'hours_per_week <= 38': [{'hours_per_week <= 25': [{'race = White': [{'hours_per_week <= 10': ['<=50K',
#                               {'occupation = Sales': ['<=50K',
#                                 {'occupation = Machine-op-inspct': ['<=50K',
#                                   '>50K']}]}]},
#                             '<=50K']},
#                           '<=50K']},
#                         {'workclass = Self-emp-inc': [{'age <= 33': ['<=50K',
#                             '>50K']},
#                           {'native_countr = Cuba': ['>50K',
#                             {'native_countr = Canada': ['>50K',
#                               {'fnlwgt <= 164190': [{'occupation = Exec-managerial': ['>50K',
#                                   {'occupation = Transport-moving': ['<=50K',
#                                     {'fnlwgt <= 157747': [{'occupation = Machine-op-inspct': ['>50K',
#                                         {'hours_per_week <= 40': [{'occupation = Sales': ['>50K',
#                                             '<=50K']},
#                                           '<=50K']}]},
#                                       {'age <= 34': ['>50K', '<=50K']}]}]}]},
#                                 {'fnlwgt <= 166606': ['<=50K',
#                                   {'age <= 33': [{'fnlwgt <= 172304': ['<=50K',
#                                       {'fnlwgt <= 173005': ['>50K',
#                                         {'fnlwgt <= 176862': ['<=50K',
#                                           {'race = Asian-Pac-Islander': ['<=50K',
#                                             {'hours_per_week <= 55': [{'education_num <= 10': [{'native_countr = Mexico': ['<=50K',
#                                                   {'fnlwgt <= 330715': [{'fnlwgt <= 189368': [{'fnlwgt <= 181091': [{'occupation = Craft-repair': ['>50K',
#                                                           '<=50K']},
#                                                         {'occupation = Adm-clerical': ['<=50K',
#                                                           '>50K']}]},
#                                                       {'fnlwgt <= 199248': ['<=50K',
#                                                         {'age <= 30': [{'hours_per_week <= 50': [{'fnlwgt <= 231826': [{'sex = Male': ['>50K',
#                                                                 '<=50K']},
#                                                               {'occupation = Adm-clerical': ['>50K',
#                                                                 {'occupation = Armed-Forces': ['>50K',
#                                                                   '<=50K']}]}]},
#                                                             '>50K']},
#                                                           {'capital_gain <= 4064': [{'fnlwgt <= 199539': ['>50K',
#                                                               {'hours_per_week <= 45': [{'occupation = Prof-specialty': ['>50K',
#                                                                   {'occupation = Exec-managerial': ['>50K',
#                                                                     {'relationship = Husband': [{'occupation = Tech-support': ['>50K',
#                                                                         {'fnlwgt <= 246439': ['<=50K',
#                                                                           {'fnlwgt <= 260782': ['>50K',
#                                                                             '<=50K']}]}]},
#                                                                       '<=50K']}]}]},
#                                                                 {'occupation = Craft-repair': ['>50K',
#                                                                   '<=50K']}]}]},
#                                                             '>50K']}]}]}]},
#                                                     {'occupation = Machine-op-inspct': ['<=50K',
#                                                       {'native_countr = United-States': [{'occupation = Adm-clerical': [{'fnlwgt <= 364657': ['>50K',
#                                                             '<=50K']},
#                                                           {'capital_loss <= 0': [{'occupation = Handlers-cleaners': ['>50K',
#                                                               {'fnlwgt <= 334744': ['>50K',
#                                                                 {'workclass = Federal-gov': ['>50K',
#                                                                   {'fnlwgt <= 368675': ['<=50K',
#                                                                     {'occupation = Sales': ['>50K',
#                                                                       {'hours_per_week <= 40': ['<=50K',
#                                                                         '>50K']}]}]}]}]}]},
#                                                             '>50K']}]},
#                                                         '>50K']}]}]}]},
#                                                 {'capital_gain <= 3411': [{'workclass = Private': [{'fnlwgt <= 197023': ['<=50K',
#                                                       {'fnlwgt <= 206541': ['>50K',
#                                                         {'fnlwgt <= 247444': ['<=50K',
#                                                           {'occupation = Exec-managerial': ['>50K',
#                                                             {'fnlwgt <= 252646': ['>50K',
#                                                               '<=50K']}]}]}]}]},
#                                                     '<=50K']},
#                                                   '>50K']}]},
#                                               {'education_num <= 10': [{'hours_per_week <= 60': [{'fnlwgt <= 231263': ['>50K',
#                                                     {'workclass = Local-gov': ['>50K',
#                                                       '<=50K']}]},
#                                                   '<=50K']},
#                                                 '>50K']}]}]}]}]}]},
# ...
#                                 '>50K']},
#                               {'capital_gain <= 0': [{'fnlwgt <= 48102': [{'marital_status = Widowed': ['<=50K',
#                                     '>50K']},
#                                   {'native_countr = Jamaica': ['>50K',
#                                     {'education_num <= 13': [{'capital_loss <= 1408': [{'marital_status = Married-spouse-absent': [{'fnlwgt <= 204584': ['<=50K',
#                                             '>50K']},
#                                           {'native_countr = Hungary': ['>50K',
#                                             {'native_countr = United-States': [{'age <= 50': [{'marital_status = Separated': ['>50K',
#                                                   {'workclass = Local-gov': [{'relationship = Unmarried': ['<=50K',
#                                                       '>50K']},
#                                                     {'workclass = Self-emp-inc': ['>50K',
#                                                       {'occupation = Prof-specialty': ['<=50K',
#                                                         {'workclass = Federal-gov': ['>50K',
#                                                           {'fnlwgt <= 162236': ['<=50K',
#                                                             {'fnlwgt <= 166809': ['>50K',
#                                                               '<=50K']}]}]}]}]}]}]},
#                                                 {'age <= 57': [{'fnlwgt <= 93415': [{'fnlwgt <= 88073': ['<=50K',
#                                                       '>50K']},
#                                                     '<=50K']},
#                                                   {'marital_status = Widowed': [{'sex = Male': ['>50K',
#                                                       {'fnlwgt <= 185338': ['>50K',
#                                                         '<=50K']}]},
#                                                     {'age <= 63': [{'age <= 59': ['<=50K',
#                                                         {'fnlwgt <= 230568': [{'age <= 61': [{'fnlwgt <= 198542': ['<=50K',
#                                                               '>50K']},
#                                                             '>50K']},
#                                                           '<=50K']}]},
#                                                       '<=50K']}]}]}]},
#                                               '<=50K']}]}]},
#                                         {'workclass = Private': [{'fnlwgt <= 109015': ['<=50K',
#                                             '>50K']},
#                                           '<=50K']}]},
#                                       {'fnlwgt <= 96798': ['<=50K',
#                                         {'age <= 68': [{'occupation = Exec-managerial': [{'age <= 51': [{'marital_status = Widowed': ['>50K',
#                                                 '<=50K']},
#                                               '>50K']},
#                                             {'relationship = Not-in-family': [{'hours_per_week <= 32': ['>50K',
#                                                 {'fnlwgt <= 181755': [{'fnlwgt <= 169785': [{'age <= 55': [{'fnlwgt <= 138370': ['<=50K',
#                                                         {'marital_status = Never-married': ['<=50K',
#                                                           '>50K']}]},
#                                                       '>50K']},
#                                                     '>50K']},
#                                                   {'hours_per_week <= 35': ['>50K',
#                                                     {'race = Black': ['>50K',
#                                                       {'workclass = Private': [{'age <= 52': ['<=50K',
#                                                           '>50K']},
#                                                         '<=50K']}]}]}]}]},
#                                               '<=50K']}]},
#                                           '<=50K']}]}]}]}]},
#                                 '<=50K']}]}]}]}]}]}]}]}]},
#               {'sex = Male': [{'native_countr = India': ['>50K',
#                   {'marital_status = Divorced': [{'fnlwgt <= 259323': ['<=50K',
#                       '>50K']},
#                     {'age <= 32': ['<=50K',
#                       {'fnlwgt <= 201764': [{'workclass = Self-emp-not-inc': [{'hours_per_week <= 20': ['<=50K',
#                             {'capital_loss <= 0': [{'fnlwgt <= 49156': ['<=50K',
#                                 '>50K']},
#                               '<=50K']}]},
#                           {'native_countr = United-States': ['>50K',
#                             '<=50K']}]},
#                         {'fnlwgt <= 225780': [{'marital_status = Separated': ['>50K',
#                             '<=50K']},
#                           {'capital_gain <= 0': [{'relationship = Own-child': ['<=50K',
#                               '>50K']},
#                             '<=50K']}]}]}]}]}]},
#                 {'hours_per_week <= 32': ['<=50K',
#                   {'race = White': [{'fnlwgt <= 101950': ['<=50K',
#                       {'education_num <= 15': [{'native_countr = United-States': ['<=50K',
#                           '>50K']},
#                         {'occupation = Prof-specialty': [{'native_countr = United-States': [{'marital_status = Never-married': ['<=50K',
#                               '>50K']},
#                             '<=50K']},
#                           '>50K']}]}]},
#                     '<=50K']}]}]}]},
#             {'capital_loss <= 3683': ['>50K', '<=50K']}]},
#           {'education_num <= 14': [{'occupation = Exec-managerial': [{'age <= 38': [{'marital_status = Never-married': [{'education_num <= 13': [{'race = Black': ['>50K',
#                       {'sex = Male': ['<=50K',
#                         {'workclass = Self-emp-inc': ['>50K',
#                           {'fnlwgt <= 170276': [{'age <= 31': ['<=50K',
#                               {'hours_per_week <= 55': ['>50K', '<=50K']}]},
#                             {'relationship = Unmarried': ['>50K',
#                               '<=50K']}]}]}]}]},
#                     {'fnlwgt <= 174215': [{'hours_per_week <= 55': ['>50K',
#                         '<=50K']},
#                       '<=50K']}]},
#                   {'hours_per_week <= 60': [{'age <= 32': [{'hours_per_week <= 45': ['<=50K',
#                         {'marital_status = Married-spouse-absent': ['<=50K',
#                           '>50K']}]},
#                       {'sex = Male': [{'age <= 37': ['>50K', '<=50K']},
#                         {'workclass = State-gov': ['>50K', '<=50K']}]}]},
#                     '<=50K']}]},
#                 {'fnlwgt <= 341439': [{'workclass = Self-emp-not-inc': [{'fnlwgt <= 275445': [{'capital_loss <= 0': ['<=50K',
#                         '>50K']},
#                       '>50K']},
#                     {'hours_per_week <= 50': [{'capital_loss <= 1816': [{'age <= 51': [{'fnlwgt <= 63042': ['>50K',
#                             {'capital_loss <= 1408': [{'fnlwgt <= 123713': [{'relationship = Unmarried': ['>50K',
#                                   {'age <= 39': ['>50K', '<=50K']}]},
#                                 {'marital_status = Never-married': [{'sex = Male': [{'education_num <= 13': [{'fnlwgt <= 187830': ['>50K',
#                                         '<=50K']},
#                                       '>50K']},
#                                     '<=50K']},
#                                   {'age <= 48': [{'age <= 41': [{'native_countr = United-States': ['<=50K',
#                                         '>50K']},
#                                       {'fnlwgt <= 193755': ['>50K',
#                                         {'fnlwgt <= 253596': ['<=50K',
#                                           '>50K']}]}]},
#                                     '<=50K']}]}]},
#                               '>50K']}]},
#                           {'fnlwgt <= 46087': ['<=50K',
#                             {'marital_status = Separated': ['<=50K',
#                               '>50K']}]}]},
#                         '>50K']},
#                       {'age <= 45': [{'age <= 43': [{'age <= 39': ['<=50K',
#                             '>50K']},
#                           '<=50K']},
#                         {'age <= 58': ['>50K', '<=50K']}]}]}]},
#                   '<=50K']}]},
#               {'sex = Male': [{'hours_per_week <= 70': [{'occupation = Transport-moving': ['<=50K',
#                     {'fnlwgt <= 188774': [{'fnlwgt <= 86298': [{'age <= 50': [{'fnlwgt <= 33975': [{'fnlwgt <= 33117': ['<=50K',
#                               '>50K']},
#                             {'hours_per_week <= 50': [{'hours_per_week <= 45': ['<=50K',
#                                 {'occupation = Sales': ['>50K', '<=50K']}]},
#                               '<=50K']}]},
#                           {'age <= 53': ['>50K',
#                             {'fnlwgt <= 60449': ['<=50K', '>50K']}]}]},
#                         {'workclass = Self-emp-not-inc': [{'age <= 30': ['>50K',
#                             {'occupation = Protective-serv': ['>50K',
#                               '<=50K']}]},
#                           {'age <= 42': [{'workclass = Private': [{'hours_per_week <= 43': ['<=50K',
#                                 {'fnlwgt <= 180477': [{'age <= 34': [{'fnlwgt <= 119522': ['<=50K',
#                                       {'fnlwgt <= 159888': [{'fnlwgt <= 154120': ['<=50K',
#                                           '>50K']},
#                                         '<=50K']}]},
#                                     {'education_num <= 13': [{'relationship = Not-in-family': [{'marital_status = Never-married': ['<=50K',
#                                           '>50K']},
#                                         '<=50K']},
#                                       '>50K']}]},
#                                   '<=50K']}]},
#                               {'fnlwgt <= 177937': ['<=50K', '>50K']}]},
#                             {'fnlwgt <= 148437': [{'fnlwgt <= 115932': [{'marital_status = Never-married': ['<=50K',
#                                   '>50K']},
#                                 {'workclass = State-gov': ['>50K', '<=50K']}]},
#                               {'relationship = Unmarried': ['<=50K',
#                                 '>50K']}]}]}]}]},
#                       {'fnlwgt <= 229148': [{'marital_status = Never-married': ['<=50K',
#                           {'relationship = Own-child': ['>50K',
#                             {'occupation = Protective-serv': ['>50K',
#                               '<=50K']}]}]},
#                         {'fnlwgt <= 315640': [{'hours_per_week <= 60': [{'age <= 46': [{'age <= 38': [{'fnlwgt <= 312055': [{'fnlwgt <= 235271': ['>50K',
#                                     {'fnlwgt <= 263307': ['<=50K',
#                                       {'hours_per_week <= 50': [{'fnlwgt <= 285000': ['<=50K',
#                                           {'fnlwgt <= 305379': ['>50K',
#                                             '<=50K']}]},
#                                         '>50K']}]}]},
#                                   '>50K']},
#                                 '<=50K']},
#                               {'fnlwgt <= 243929': ['<=50K', '>50K']}]},
#                             '<=50K']},
#                           {'fnlwgt <= 332243': ['<=50K',
#                             {'education_num <= 13': [{'fnlwgt <= 351278': ['<=50K',
#                                 {'fnlwgt <= 351576': ['>50K',
#                                   {'workclass = Self-emp-inc': ['>50K',
#                                     {'fnlwgt <= 403433': [{'fnlwgt <= 371886': ['<=50K',
#                                         {'age <= 34': ['<=50K', '>50K']}]},
#                                       '<=50K']}]}]}]},
#                               {'hours_per_week <= 48': ['<=50K',
#                                 {'fnlwgt <= 427382': ['>50K',
#                                   '<=50K']}]}]}]}]}]}]}]},
#                   '<=50K']},
#                 {'fnlwgt <= 272090': [{'hours_per_week <= 43': [{'fnlwgt <= 81259': ['<=50K',
#                       '>50K']},
#                     {'hours_per_week <= 45': [{'fnlwgt <= 213334': ['<=50K',
#                         {'fnlwgt <= 222011': ['>50K', '<=50K']}]},
#                       {'relationship = Unmarried': [{'native_countr = Poland': ['>50K',
#                           '<=50K']},
#                         {'race = Other': ['>50K',
#                           {'fnlwgt <= 220640': [{'fnlwgt <= 137527': [{'fnlwgt <= 22494': ['>50K',
#                                 {'workclass = Self-emp-inc': ['>50K',
#                                   {'occupation = Sales': [{'age <= 38': ['>50K',
#                                       '<=50K']},
#                                     {'hours_per_week <= 46': ['>50K',
#                                       '<=50K']}]}]}]},
#                               {'occupation = Prof-specialty': [{'fnlwgt <= 188503': [{'fnlwgt <= 187098': [{'fnlwgt <= 182714': [{'fnlwgt <= 177114': [{'fnlwgt <= 175642': [{'age <= 53': [{'age <= 47': [{'hours_per_week <= 55': ['<=50K',
#                                                 '>50K']},
#                                               '>50K']},
#                                             '<=50K']},
#                                           '<=50K']},
#                                         '>50K']},
#                                       '<=50K']},
#                                     '>50K']},
#                                   {'fnlwgt <= 211286': ['<=50K', '>50K']}]},
#                                 '<=50K']}]},
#                             '<=50K']}]}]}]}]},
#                   {'capital_gain <= 1506': [{'fnlwgt <= 353263': [{'race = White': [{'relationship = Not-in-family': [{'capital_loss <= 0': [{'fnlwgt <= 351810': [{'education_num <= 13': [{'fnlwgt <= 288398': ['<=50K',
#                                   '>50K']},
#                                 '<=50K']},
#                               '>50K']},
#                             '>50K']},
#                           '<=50K']},
#                         '>50K']},
#                       '<=50K']},
#                     '>50K']}]}]}]},
#             {'age <= 32': [{'fnlwgt <= 196025': ['<=50K',
#                 {'hours_per_week <= 50': ['>50K', '<=50K']}]},
#               {'capital_loss <= 0': [{'race = White': [{'relationship = Other-relative': ['<=50K',
#                     {'fnlwgt <= 37314': ['<=50K',
#                       {'occupation = Farming-fishing': ['<=50K',
#                         {'age <= 58': [{'age <= 50': [{'fnlwgt <= 197054': [{'fnlwgt <= 126161': [{'workclass = State-gov': ['<=50K',
#                                   {'hours_per_week <= 60': [{'fnlwgt <= 121124': ['>50K',
#                                       '<=50K']},
#                                     '<=50K']}]},
#                                 '>50K']},
#                               {'occupation = Prof-specialty': [{'fnlwgt <= 203763': ['<=50K',
#                                   {'fnlwgt <= 255503': ['>50K',
#                                     {'workclass = Self-emp-not-inc': ['>50K',
#                                       {'education_num <= 15': ['<=50K',
#                                         {'hours_per_week <= 80': [{'fnlwgt <= 410867': ['>50K',
#                                             '<=50K']},
#                                           '<=50K']}]}]}]}]},
#                                 '<=50K']}]},
#                             '>50K']},
#                           {'fnlwgt <= 99359': ['<=50K', '>50K']}]}]}]}]},
#                   '>50K']},
#                 '>50K']}]}]}]}]}]},
#     {'capital_gain <= 7978': [{'capital_gain <= 7430': ['>50K',
#         {'relationship = Other-relative': ['>50K', '<=50K']}]},
#       {'age <= 20': [{'capital_gain <= 14084': ['>50K', '<=50K']},
#         {'workclass = Self-emp-not-inc': [{'age <= 54': ['>50K',
#             {'hours_per_week <= 55': ['>50K', '<=50K']}]},
#           '>50K']}]}]}]}]}

# %%
count_depth(tree)
# Out:
# 152

# %%
count_nodes(tree)
# Out:
# 7055

# %%
pruned_tree = post_pruning(tree ,df_train,df_test)

# %%
pruned_tree
# Out:
# {'marital_status = Married-civ-spouse': [{'capital_gain <= 5013': [{'education_num <= 11': [{'education_num <= 8': [{'age <= 37': ['<=50K',
#           {'hours_per_week <= 29': ['<=50K',
#             {'capital_loss <= 1740': ['<=50K',
#               {'capital_loss <= 1977': ['>50K', '<=50K']}]}]}]},
#         {'age <= 35': [{'age <= 24': ['<=50K',
#             {'capital_loss <= 1740': [{'education_num <= 9': [{'hours_per_week <= 37': ['<=50K',
#                   {'occupation = Exec-managerial': ['<=50K',
#                     {'occupation = Protective-serv': ['<=50K',
#                       {'hours_per_week <= 45': [{'relationship = Wife': [{'workclass = Federal-gov': ['>50K',
#                             '<=50K']},
#                           {'occupation = Farming-fishing': ['<=50K',
#                             {'race = White': [{'fnlwgt <= 39232': ['<=50K',
#                                 {'native_countr = Yugoslavia': ['>50K',
#                                   {'occupation = Other-service': ['<=50K',
#                                     {'native_countr = Cuba': ['>50K',
#                                       {'fnlwgt <= 39257': ['>50K',
#                                         {'age <= 26': ['<=50K',
#                                           {'age <= 34': [{'capital_loss <= 0': [{'occupation = Handlers-cleaners': [{'fnlwgt <= 125762': ['<=50K',
#                                                   {'fnlwgt <= 174201': [{'age <= 32': ['>50K',
#                                                       '<=50K']},
#                                                     '<=50K']}]},
#                                                 {'occupation = Adm-clerical': [{'capital_gain <= 3464': [{'workclass = Federal-gov': ['>50K',
#                                                       '<=50K']},
#                                                     '>50K']},
#                                                   '<=50K']}]},
#                                               '<=50K']},
#                                             '<=50K']}]}]}]}]}]}]},
#                               '<=50K']}]}]},
#                         '<=50K']}]}]}]},
#                 {'fnlwgt <= 151053': [{'age <= 31': ['<=50K',
#                     {'fnlwgt <= 27565': ['>50K',
#                       {'occupation = Other-service': ['<=50K',
#                         {'fnlwgt <= 33417': ['<=50K',
#                           {'fnlwgt <= 34080': ['>50K',
#                             {'fnlwgt <= 100446': [{'hours_per_week <= 48': ['<=50K',
#                                 {'occupation = Craft-repair': ['<=50K',
#                                   {'occupation = Farming-fishing': ['<=50K',
#                                     {'hours_per_week <= 55': [{'fnlwgt <= 38948': ['<=50K',
#                                         '>50K']},
#                                       '<=50K']}]}]}]},
#                               {'fnlwgt <= 103323': ['>50K',
#                                 {'occupation = Exec-managerial': ['>50K',
#                                   '<=50K']}]}]}]}]}]}]}]},
#                   {'capital_loss <= 1485': [{'age <= 29': ['<=50K',
#                       {'hours_per_week <= 38': ['<=50K',
#                         {'workclass = Self-emp-inc': [{'age <= 33': ['<=50K',
#                             '>50K']},
#                           '<=50K']}]}]},
#                     '<=50K']}]}]},
#               {'capital_loss <= 1977': ['>50K', '<=50K']}]}]},
#           {'capital_loss <= 1844': [{'hours_per_week <= 34': [{'relationship = Wife': [{'occupation = Exec-managerial': [{'hours_per_week <= 30': ['>50K',
#                     '<=50K']},
#                   '<=50K']},
#                 '<=50K']},
#               {'occupation = Exec-managerial': [{'workclass = Self-emp-not-inc': ['<=50K',
#                   {'workclass = Local-gov': [{'race = White': [{'age <= 41': ['<=50K',
#                         {'fnlwgt <= 195453': ['>50K', '<=50K']}]},
#                       '>50K']},
#                     {'capital_loss <= 1485': [{'fnlwgt <= 83922': [{'fnlwgt <= 31964': ['>50K',
#                           {'workclass = Federal-gov': ['>50K',
#                             {'education_num <= 10': [{'age <= 58': ['<=50K',
#                                 '>50K']},
#                               '>50K']}]}]},
#                         '>50K']},
#                       '<=50K']}]}]},
#                 {'occupation = Farming-fishing': [{'age <= 64': [{'fnlwgt <= 157749': [{'education_num <= 10': ['<=50K',
#                         {'fnlwgt <= 40666': ['<=50K', '>50K']}]},
#                       '<=50K']},
#                     '<=50K']},
#                   {'education_num <= 9': [{'capital_loss <= 1485': [{'occupation = Other-service': ['<=50K',
#                         {'workclass = Federal-gov': [{'hours_per_week <= 38': ['<=50K',
#                             {'occupation = Adm-clerical': [{'age <= 43': ['>50K',
#                                 {'age <= 47': ['>50K',
#                                   {'race = White': ['>50K', '<=50K']}]}]},
#                               '<=50K']}]},
#                           {'hours_per_week <= 40': [{'relationship = Wife': [{'age <= 50': [{'workclass = Local-gov': ['>50K',
#                                   {'capital_gain <= 0': [{'occupation = Tech-support': ['<=50K',
#                                       {'fnlwgt <= 200569': [{'fnlwgt <= 178002': [{'fnlwgt <= 57600': ['<=50K',
#                                             {'fnlwgt <= 106422': ['>50K',
#                                               {'race = White': [{'fnlwgt <= 117502': ['<=50K',
#                                                   {'hours_per_week <= 38': ['<=50K',
#                                                     {'workclass = State-gov': ['<=50K',
#                                                       {'occupation = Machine-op-inspct': ['<=50K',
#                                                         '>50K']}]}]}]},
#                                                 '<=50K']}]}]},
#                                           '<=50K']},
#                                         '>50K']}]},
#                                     '<=50K']}]},
#                                 '<=50K']},
#                               {'fnlwgt <= 498785': [{'age <= 46': [{'capital_gain <= 3103': [{'occupation = Sales': ['<=50K',
#                                       {'fnlwgt <= 104772': ['<=50K',
#                                         {'workclass = State-gov': ['<=50K',
#                                           {'workclass = Self-emp-not-inc': ['<=50K',
#                                             {'fnlwgt <= 114157': ['<=50K',
#                                               {'native_countr = Germany': ['>50K',
#                                                 {'fnlwgt <= 114251': ['>50K',
#                                                   {'fnlwgt <= 116736': ['<=50K',
#                                                     {'fnlwgt <= 116960': ['>50K',
#                                                       {'race = Other': ['<=50K',
#                                                         {'fnlwgt <= 456236': [{'fnlwgt <= 358886': [{'hours_per_week <= 35': ['<=50K',
#                                                               {'age <= 41': ['<=50K',
#                                                                 {'occupation = Craft-repair': [{'age <= 43': [{'fnlwgt <= 211860': ['>50K',
#                                                                       '<=50K']},
#                                                                     '<=50K']},
#                                                                   {'occupation = Tech-support': ['>50K',
#                                                                     {'fnlwgt <= 153254': ['<=50K',
#                                                                       {'fnlwgt <= 162187': [{'race = White': ['>50K',
#                                                                           '<=50K']},
#                                                                         {'fnlwgt <= 193672': ['<=50K',
#                                                                           {'fnlwgt <= 195258': ['>50K',
#                                                                             {'fnlwgt <= 334946': [{'fnlwgt <= 271828': [{'fnlwgt <= 263568': ['<=50K',
#                                                                                   '>50K']},
#                                                                                 '<=50K']},
#                                                                               '<=50K']}]}]}]}]}]}]}]}]},
#                                                             '<=50K']},
#                                                           '<=50K']}]}]}]}]}]}]}]}]}]}]},
#                                     '<=50K']},
#                                   '<=50K']},
#                                 {'fnlwgt <= 531055': ['>50K',
#                                   {'fnlwgt <= 549174': ['<=50K',
#                                     {'native_countr = United-States': [{'age <= 58': ['>50K',
#                                         '<=50K']},
#                                       '<=50K']}]}]}]}]},
#                             {'capital_loss <= 0': [{'workclass = Self-emp-not-inc': ['<=50K',
#                                 {'hours_per_week <= 85': [{'age <= 43': [{'occupation = Tech-support': ['>50K',
#                                       {'hours_per_week <= 75': [{'fnlwgt <= 30682': ['>50K',
#                                           {'fnlwgt <= 38948': ['<=50K',
#                                             {'workclass = Self-emp-inc': [{'fnlwgt <= 151089': ['<=50K',
#                                                 '>50K']},
#                                               {'fnlwgt <= 40077': ['>50K',
#                                                 {'workclass = State-gov': ['>50K',
#                                                   {'age <= 37': [{'fnlwgt <= 76417': ['<=50K',
#                                                       {'fnlwgt <= 110713': ['>50K',
#                                                         '<=50K']}]},
#                                                     {'fnlwgt <= 165466': [{'occupation = Transport-moving': ['<=50K',
#                                                         {'hours_per_week <= 42': ['>50K',
#                                                           '<=50K']}]},
#                                                       {'age <= 42': [{'hours_per_week <= 44': ['<=50K',
#                                                           {'fnlwgt <= 246463': ['<=50K',
#                                                             {'fnlwgt <= 259846': ['>50K',
#                                                               {'age <= 39': [{'occupation = Craft-repair': ['<=50K',
#                                                                   '>50K']},
#                                                                 '<=50K']}]}]}]},
#                                                         '<=50K']}]}]}]}]}]}]}]},
#                                         '<=50K']}]},
#                                     '<=50K']},
#                                   '<=50K']}]},
#                               '>50K']}]}]}]},
#                       '<=50K']},
#                     {'workclass = Self-emp-not-inc': [{'fnlwgt <= 343748': [{'occupation = Tech-support': ['>50K',
#                           '<=50K']},
#                         '>50K']},
#                       {'occupation = Handlers-cleaners': ['<=50K',
#                         {'fnlwgt <= 151089': [{'workclass = Self-emp-inc': ['>50K',
#                             {'occupation = Tech-support': [{'age <= 59': [{'fnlwgt <= 47392': ['>50K',
#                                   {'fnlwgt <= 52781': ['<=50K',
#                                     {'age <= 51': ['>50K', '<=50K']}]}]},
#                                 '<=50K']},
#                               {'fnlwgt <= 145409': [{'fnlwgt <= 71269': [{'hours_per_week <= 70': [{'occupation = Adm-clerical': [{'hours_per_week <= 45': [{'fnlwgt <= 48271': [{'age <= 49': ['<=50K',
#                                             '>50K']},
#                                           '<=50K']},
#                                         '>50K']},
#                                       {'age <= 37': ['<=50K',
#                                         {'hours_per_week <= 47': [{'hours_per_week <= 45': [{'occupation = Other-service': ['<=50K',
#                                               {'age <= 43': ['<=50K',
#                                                 {'fnlwgt <= 30118': ['<=50K',
#                                                   {'fnlwgt <= 43221': ['>50K',
#                                                     '<=50K']}]}]}]},
#                                             '>50K']},
#                                           {'education_num <= 10': ['<=50K',
#                                             {'age <= 43': ['<=50K',
#                                               '>50K']}]}]}]}]},
#                                     '>50K']},
#                                   {'fnlwgt <= 82050': [{'age <= 47': ['>50K',
#                                       {'fnlwgt <= 80123': ['<=50K', '>50K']}]},
#                                     {'fnlwgt <= 83411': ['<=50K',
#                                       {'age <= 45': [{'capital_gain <= 2829': [{'hours_per_week <= 60': [{'hours_per_week <= 48': [{'fnlwgt <= 126845': [{'age <= 39': ['<=50K',
#                                                   {'occupation = Prof-specialty': ['>50K',
#                                                     '<=50K']}]},
#                                                 '<=50K']},
#                                               {'hours_per_week <= 50': [{'occupation = Adm-clerical': ['<=50K',
#                                                   '>50K']},
#                                                 '<=50K']}]},
#                                             '<=50K']},
#                                           '>50K']},
#                                         {'fnlwgt <= 138999': ['<=50K',
#                                           '>50K']}]}]}]}]},
#                                 {'fnlwgt <= 147989': ['<=50K',
#                                   {'age <= 47': [{'occupation = Transport-moving': ['<=50K',
#                                       '>50K']},
#                                     '<=50K']}]}]}]}]},
#                           {'capital_gain <= 3103': [{'capital_gain <= 2407': [{'occupation = Protective-serv': [{'age <= 57': ['>50K',
#                                   '<=50K']},
#                                 {'age <= 43': [{'occupation = Other-service': ['<=50K',
#                                     {'fnlwgt <= 154076': ['>50K',
#                                       {'fnlwgt <= 176155': ['<=50K',
#                                         {'fnlwgt <= 177285': ['>50K',
#                                           {'hours_per_week <= 38': ['>50K',
#                                             {'workclass = Federal-gov': [{'occupation = Craft-repair': ['<=50K',
#                                                 {'fnlwgt <= 205675': ['>50K',
#                                                   {'hours_per_week <= 45': ['>50K',
#                                                     '<=50K']}]}]},
#                                               {'fnlwgt <= 469454': [{'fnlwgt <= 449578': [{'fnlwgt <= 421837': [{'native_countr = Mexico': ['<=50K',
#                                                       {'native_countr = Dominican-Republic': ['<=50K',
#                                                         {'occupation = Transport-moving': ['<=50K',
#                                                           {'hours_per_week <= 40': ['<=50K',
#                                                             {'race = White': [{'fnlwgt <= 347653': [{'hours_per_week <= 48': ['>50K',
#                                                                   {'fnlwgt <= 319685': [{'age <= 39': [{'occupation = Tech-support': ['<=50K',
#                                                                         {'workclass = Self-emp-inc': ['>50K',
#                                                                           {'fnlwgt <= 276552': [{'occupation = Machine-op-inspct': ['<=50K',
#                                                                               {'fnlwgt <= 203836': [{'hours_per_week <= 50': ['>50K',
#                                                                                   '<=50K']},
#                                                                                 {'fnlwgt <= 213512': ['<=50K',
#                                                                                   '>50K']}]}]},
#                                                                             '>50K']}]}]},
#                                                                       '<=50K']},
#                                                                     '<=50K']}]},
#                                                                 '<=50K']},
#                                                               '>50K']}]}]}]}]},
#                                                     '>50K']},
#                                                   '<=50K']},
#                                                 '>50K']}]}]}]}]}]}]},
#                                   {'age <= 44': ['>50K',
#                                     {'race = Black': [{'occupation = Transport-moving': ['<=50K',
#                                         {'occupation = Machine-op-inspct': ['<=50K',
#                                           '>50K']}]},
#                                       {'occupation = Tech-support': ['>50K',
#                                         {'age <= 62': [{'capital_loss <= 1485': [{'hours_per_week <= 42': [{'fnlwgt <= 346014': [{'fnlwgt <= 339954': [{'hours_per_week <= 40': [{'race = Other': ['<=50K',
#                                                       {'fnlwgt <= 167617': ['<=50K',
#                                                         {'fnlwgt <= 178054': ['>50K',
#                                                           {'fnlwgt <= 182541': ['<=50K',
#                                                             {'age <= 45': ['>50K',
#                                                               '<=50K']}]}]}]}]},
#                                                     '<=50K']},
#                                                   '<=50K']},
#                                                 '>50K']},
#                                               {'hours_per_week <= 48': ['>50K',
#                                                 {'fnlwgt <= 161838': ['<=50K',
#                                                   {'fnlwgt <= 176240': ['>50K',
#                                                     {'fnlwgt <= 186479': ['<=50K',
#                                                       '>50K']}]}]}]}]},
#                                             '<=50K']},
#                                           '<=50K']}]}]}]}]}]},
#                               '>50K']},
#                             '<=50K']}]}]}]}]}]}]}]},
#             {'capital_loss <= 1977': ['>50K',
#               {'capital_loss <= 2149': ['<=50K',
#                 {'capital_loss <= 2415': [{'capital_loss <= 2377': [{'capital_loss <= 2174': ['>50K',
#                       {'age <= 66': [{'sex = Male': ['<=50K', '>50K']},
#                         '>50K']}]},
#                     '>50K']},
#                   '<=50K']}]}]}]}]}]},
#       {'capital_loss <= 1740': [{'age <= 27': ['<=50K',
#           {'hours_per_week <= 30': [{'sex = Male': [{'age <= 29': ['<=50K',
#                 {'occupation = Farming-fishing': ['<=50K',
#                   {'fnlwgt <= 142370': [{'age <= 41': ['<=50K',
#                       {'capital_gain <= 0': [{'fnlwgt <= 113868': [{'fnlwgt <= 102359': ['<=50K',
#                             '>50K']},
#                           '<=50K']},
#                         '<=50K']}]},
#                     '<=50K']}]}]},
#               {'fnlwgt <= 96219': ['<=50K',
#                 {'hours_per_week <= 5': ['<=50K',
#                   {'native_countr = Poland': ['<=50K',
#                     {'age <= 48': [{'fnlwgt <= 277390': ['>50K',
#                         {'hours_per_week <= 17': ['>50K', '<=50K']}]},
#                       {'fnlwgt <= 202384': ['<=50K', '>50K']}]}]}]}]}]},
#             {'education_num <= 13': [{'occupation = Exec-managerial': [{'capital_loss <= 1485': [{'workclass = Self-emp-not-inc': [{'age <= 60': [{'hours_per_week <= 35': ['<=50K',
#                         {'age <= 48': ['<=50K', '>50K']}]},
#                       '<=50K']},
#                     {'capital_gain <= 3103': [{'age <= 65': [{'hours_per_week <= 65': [{'fnlwgt <= 76196': [{'age <= 55': [{'age <= 30': ['<=50K',
#                                 {'age <= 35': ['>50K',
#                                   {'fnlwgt <= 30840': ['>50K',
#                                     {'age <= 46': ['<=50K', '>50K']}]}]}]},
#                               '<=50K']},
#                             {'fnlwgt <= 92775': ['>50K',
#                               {'hours_per_week <= 48': [{'fnlwgt <= 185413': [{'fnlwgt <= 128796': [{'age <= 38': [{'age <= 33': ['>50K',
#                                         {'hours_per_week <= 44': ['>50K',
#                                           '<=50K']}]},
#                                       '>50K']},
#                                     {'native_countr = United-States': [{'hours_per_week <= 32': ['<=50K',
#                                         {'education_num <= 12': [{'fnlwgt <= 159670': ['<=50K',
#                                             '>50K']},
#                                           {'workclass = Local-gov': ['<=50K',
#                                             '>50K']}]}]},
#                                       '>50K']}]},
#                                   {'fnlwgt <= 193882': ['>50K',
#                                     {'fnlwgt <= 195212': ['<=50K',
#                                       '>50K']}]}]},
#                                 '>50K']}]}]},
#                           {'fnlwgt <= 79531': ['>50K',
#                             {'fnlwgt <= 186932': ['<=50K',
#                               {'fnlwgt <= 246891': ['>50K',
#                                 {'hours_per_week <= 72': ['<=50K',
#                                   '>50K']}]}]}]}]},
#                         {'fnlwgt <= 191380': ['>50K', '<=50K']}]},
#                       '<=50K']}]},
#                   '<=50K']},
#                 {'occupation = Other-service': ['<=50K',
#                   {'age <= 35': [{'education_num <= 12': ['<=50K',
#                       {'native_countr = United-States': [{'age <= 34': [{'fnlwgt <= 91189': [{'workclass = Self-emp-not-inc': ['<=50K',
#                               {'hours_per_week <= 55': [{'occupation = Farming-fishing': ['>50K',
#                                   {'hours_per_week <= 47': [{'hours_per_week <= 44': [{'age <= 32': ['>50K',
#                                         '<=50K']},
#                                       '>50K']},
#                                     '<=50K']}]},
#                                 '>50K']}]},
#                             {'occupation = Farming-fishing': ['<=50K',
#                               {'age <= 33': [{'capital_gain <= 4386': [{'hours_per_week <= 75': [{'capital_gain <= 3103': [{'capital_gain <= 0': [{'occupation = Handlers-cleaners': ['<=50K',
#                                           {'race = Asian-Pac-Islander': ['>50K',
#                                             {'fnlwgt <= 444304': [{'fnlwgt <= 93884': ['>50K',
#                                                 {'relationship = Husband': [{'race = White': [{'age <= 30': [{'workclass = Self-emp-inc': ['>50K',
#                                                         {'fnlwgt <= 103651': ['<=50K',
#                                                           {'age <= 28': [{'fnlwgt <= 259840': [{'fnlwgt <= 192200': [{'fnlwgt <= 176972': [{'hours_per_week <= 50': [{'occupation = Craft-repair': ['>50K',
#                                                                       {'fnlwgt <= 149624': ['>50K',
#                                                                         '<=50K']}]},
#                                                                     '>50K']},
#                                                                   '<=50K']},
#                                                                 '>50K']},
#                                                               '<=50K']},
#                                                             {'fnlwgt <= 220915': [{'fnlwgt <= 208043': [{'occupation = Prof-specialty': ['>50K',
#                                                                   {'fnlwgt <= 173944': ['>50K',
#                                                                     '<=50K']}]},
#                                                                 '<=50K']},
#                                                               '>50K']}]}]}]},
#                                                       {'workclass = Local-gov': ['<=50K',
#                                                         {'hours_per_week <= 65': [{'fnlwgt <= 157287': [{'fnlwgt <= 149368': [{'hours_per_week <= 60': ['>50K',
#                                                                 '<=50K']},
#                                                               '<=50K']},
#                                                             {'fnlwgt <= 164197': ['>50K',
#                                                               {'fnlwgt <= 167063': ['<=50K',
#                                                                 {'fnlwgt <= 183977': ['>50K',
#                                                                   {'fnlwgt <= 193042': ['<=50K',
#                                                                     {'occupation = Craft-repair': ['>50K',
#                                                                       {'fnlwgt <= 193285': ['>50K',
#                                                                         {'fnlwgt <= 199227': ['<=50K',
#                                                                           '>50K']}]}]}]}]}]}]}]},
#                                                           '>50K']}]}]},
#                                                     '>50K']},
#                                                   {'workclass = Self-emp-not-inc': ['>50K',
#                                                     {'hours_per_week <= 33': ['>50K',
#                                                       {'fnlwgt <= 137476': ['>50K',
#                                                         '<=50K']}]}]}]}]},
#                                               '>50K']}]}]},
#                                         '>50K']},
#                                       '<=50K']},
#                                     '>50K']},
#                                   '<=50K']},
#                                 '>50K']}]}]},
#                           {'fnlwgt <= 33975': ['>50K',
#                             {'workclass = Local-gov': ['<=50K',
#                               {'occupation = Transport-moving': ['<=50K',
#                                 {'fnlwgt <= 98360': ['<=50K',
#                                   {'fnlwgt <= 105138': ['>50K',
#                                     {'workclass = Self-emp-not-inc': ['<=50K',
#                                       {'fnlwgt <= 265662': [{'fnlwgt <= 233533': [{'fnlwgt <= 200352': ['>50K',
#                                             '<=50K']},
#                                           '>50K']},
#                                         '<=50K']}]}]}]}]}]}]}]},
#                         {'native_countr = Philippines': ['>50K', '<=50K']}]}]},
#                     {'fnlwgt <= 118158': [{'education_num <= 12': [{'fnlwgt <= 102112': [{'age <= 40': ['<=50K',
#                             {'age <= 41': ['>50K',
#                               {'age <= 56': [{'capital_gain <= 0': [{'fnlwgt <= 101299': [{'hours_per_week <= 40': [{'fnlwgt <= 95902': [{'age <= 45': ['<=50K',
#                                           '>50K']},
#                                         '>50K']},
#                                       '<=50K']},
#                                     '>50K']},
#                                   '>50K']},
#                                 '>50K']}]}]},
#                           '<=50K']},
#                         {'capital_gain <= 3103': [{'native_countr = United-States': [{'hours_per_week <= 55': ['>50K',
#                               '<=50K']},
#                             '>50K']},
#                           '<=50K']}]},
#                       {'capital_loss <= 1485': [{'occupation = Farming-fishing': ['<=50K',
#                           {'occupation = Transport-moving': ['<=50K',
#                             {'fnlwgt <= 549341': [{'age <= 61': [{'native_countr = India': ['<=50K',
#                                   {'age <= 52': [{'fnlwgt <= 144778': ['>50K',
#                                       {'fnlwgt <= 146659': ['<=50K',
#                                         {'occupation = Handlers-cleaners': ['<=50K',
#                                           {'capital_gain <= 4386': [{'hours_per_week <= 55': ['>50K',
#                                               {'age <= 37': ['>50K',
#                                                 {'hours_per_week <= 84': ['>50K',
#                                                   '<=50K']}]}]},
#                                             '<=50K']}]}]}]},
#                                     {'race = White': ['>50K',
#                                       {'education_num <= 12': ['>50K',
#                                         {'workclass = Federal-gov': ['>50K',
#                                           '<=50K']}]}]}]}]},
#                                 {'workclass = Private': [{'age <= 68': [{'fnlwgt <= 138714': ['>50K',
#                                       {'fnlwgt <= 190873': ['<=50K',
#                                         '>50K']}]},
#                                     '<=50K']},
#                                   {'occupation = Sales': ['>50K',
#                                     {'fnlwgt <= 143880': ['>50K',
#                                       '<=50K']}]}]}]},
#                               '>50K']}]}]},
#                         '<=50K']}]}]}]}]},
#               {'capital_loss <= 0': [{'age <= 33': [{'native_countr = United-States': [{'fnlwgt <= 357691': [{'capital_gain <= 0': [{'race = Black': ['<=50K',
#                           {'fnlwgt <= 34452': ['<=50K',
#                             {'fnlwgt <= 167990': [{'education = Prof-school': ['>50K',
#                                 {'fnlwgt <= 106721': [{'hours_per_week <= 50': ['<=50K',
#                                     '>50K']},
#                                   '>50K']}]},
#                               {'fnlwgt <= 204074': [{'fnlwgt <= 195181': ['>50K',
#                                   '<=50K']},
#                                 '>50K']}]}]}]},
#                         '<=50K']},
#                       '>50K']},
#                     '<=50K']},
#                   {'age <= 58': [{'occupation = Adm-clerical': ['>50K',
#                       {'capital_gain <= 0': [{'occupation = Sales': [{'workclass = Self-emp-inc': ['>50K',
#                             {'hours_per_week <= 55': [{'native_countr = United-States': ['>50K',
#                                 '<=50K']},
#                               '<=50K']}]},
#                           {'age <= 40': [{'occupation = Craft-repair': ['<=50K',
#                               {'race = Asian-Pac-Islander': [{'age <= 35': ['>50K',
#                                   '<=50K']},
#                                 {'occupation = Farming-fishing': ['<=50K',
#                                   '>50K']}]}]},
#                             '>50K']}]},
#                         '<=50K']}]},
#                     '>50K']}]},
#                 '<=50K']}]}]}]},
#         {'capital_loss <= 1977': ['>50K',
#           {'capital_loss <= 2163': ['<=50K', '>50K']}]}]}]},
#     '>50K']},
#   {'capital_gain <= 6849': [{'education_num <= 12': [{'age <= 26': [{'capital_loss <= 2339': ['<=50K',
#           '>50K']},
#         {'hours_per_week <= 40': [{'capital_loss <= 2206': [{'occupation = Other-service': ['<=50K',
#               {'capital_gain <= 4650': [{'education_num <= 9': ['<=50K',
#                   {'occupation = Adm-clerical': ['<=50K',
#                     {'relationship = Not-in-family': [{'age <= 33': ['<=50K',
#                         {'workclass = State-gov': ['<=50K',
#                           {'occupation = Prof-specialty': ['<=50K',
#                             {'native_countr = Cuba': ['>50K',
#                               {'occupation = Protective-serv': ['<=50K',
#                                 {'race = White': [{'hours_per_week <= 12': ['<=50K',
#                                     {'hours_per_week <= 34': ['<=50K',
#                                       {'fnlwgt <= 356934': [{'fnlwgt <= 352056': [{'fnlwgt <= 295922': [{'fnlwgt <= 294919': [{'fnlwgt <= 200190': [{'fnlwgt <= 199763': ['<=50K',
#                                                   '>50K']},
#                                                 '<=50K']},
#                                               '>50K']},
#                                             '<=50K']},
#                                           '>50K']},
#                                         '<=50K']}]}]},
#                                   '<=50K']}]}]}]}]}]},
#                       '<=50K']}]}]},
#                 '<=50K']}]},
#             '<=50K']},
#           {'capital_loss <= 2206': [{'age <= 38': [{'education_num <= 11': [{'workclass = Private': ['<=50K',
#                   {'occupation = Farming-fishing': ['<=50K',
#                     {'native_countr = India': ['>50K',
#                       {'relationship = Not-in-family': [{'fnlwgt <= 28568': ['>50K',
#                           '<=50K']},
#                         '<=50K']}]}]}]},
#                 '<=50K']},
#               {'occupation = Other-service': ['<=50K',
#                 {'sex = Male': [{'marital_status = Never-married': [{'race = White': [{'workclass = Self-emp-not-inc': ['<=50K',
#                         {'age <= 39': ['<=50K',
#                           {'native_countr = England': ['>50K',
#                             {'hours_per_week <= 58': ['<=50K',
#                               {'fnlwgt <= 144236': ['<=50K', '>50K']}]}]}]}]},
#                       '<=50K']},
#                     '<=50K']},
#                   '<=50K']}]}]},
#             {'capital_loss <= 2339': ['<=50K',
#               {'capital_loss <= 2559': ['>50K',
#                 {'sex = Male': ['>50K', '<=50K']}]}]}]}]}]},
#       {'age <= 29': [{'capital_loss <= 1504': ['<=50K',
#           {'capital_loss <= 1564': ['>50K', '<=50K']}]},
#         {'hours_per_week <= 42': [{'capital_loss <= 2339': [{'education_num <= 14': [{'age <= 44': [{'occupation = Adm-clerical': ['<=50K',
#                   {'fnlwgt <= 408229': [{'hours_per_week <= 24': ['<=50K',
#                       {'fnlwgt <= 66278': ['<=50K',
#                         {'fnlwgt <= 344060': [{'fnlwgt <= 342642': [{'occupation = Other-service': ['<=50K',
#                               {'workclass = State-gov': ['<=50K',
#                                 {'capital_loss <= 1564': [{'capital_loss <= 1408': [{'relationship = Own-child': ['<=50K',
#                                       {'workclass = Local-gov': ['<=50K',
#                                         {'capital_gain <= 4650': ['<=50K',
#                                           '>50K']}]}]},
#                                     '>50K']},
#                                   '<=50K']}]}]},
#                             '>50K']},
#                           '<=50K']}]}]},
#                     '<=50K']}]},
#                 '<=50K']},
#               '<=50K']},
#             '>50K']},
#           {'education_num <= 14': [{'occupation = Exec-managerial': [{'age <= 38': [{'marital_status = Never-married': ['<=50K',
#                   {'hours_per_week <= 60': [{'age <= 32': [{'hours_per_week <= 45': ['<=50K',
#                         {'marital_status = Married-spouse-absent': ['<=50K',
#                           '>50K']}]},
#                       {'sex = Male': ['>50K', '<=50K']}]},
#                     '<=50K']}]},
#                 {'fnlwgt <= 341439': [{'workclass = Self-emp-not-inc': ['<=50K',
#                     {'hours_per_week <= 50': [{'capital_loss <= 1816': [{'age <= 51': ['<=50K',
#                           '>50K']},
#                         '>50K']},
#                       {'age <= 45': [{'age <= 43': [{'age <= 39': ['<=50K',
#                             '>50K']},
#                           '<=50K']},
#                         {'age <= 58': ['>50K', '<=50K']}]}]}]},
#                   '<=50K']}]},
#               {'sex = Male': [{'hours_per_week <= 70': [{'occupation = Transport-moving': ['<=50K',
#                     {'fnlwgt <= 188774': [{'fnlwgt <= 86298': ['<=50K',
#                         {'workclass = Self-emp-not-inc': ['<=50K',
#                           {'age <= 42': [{'workclass = Private': [{'hours_per_week <= 43': ['<=50K',
#                                 {'fnlwgt <= 180477': [{'age <= 34': ['<=50K',
#                                     {'education_num <= 13': [{'relationship = Not-in-family': ['>50K',
#                                         '<=50K']},
#                                       '>50K']}]},
#                                   '<=50K']}]},
#                               '<=50K']},
#                             {'fnlwgt <= 148437': ['<=50K', '>50K']}]}]}]},
#                       {'fnlwgt <= 229148': [{'marital_status = Never-married': ['<=50K',
#                           {'relationship = Own-child': ['>50K',
#                             {'occupation = Protective-serv': ['>50K',
#                               '<=50K']}]}]},
#                         '<=50K']}]}]},
#                   '<=50K']},
#                 {'fnlwgt <= 272090': [{'hours_per_week <= 43': [{'fnlwgt <= 81259': ['<=50K',
#                       '>50K']},
#                     {'hours_per_week <= 45': ['<=50K',
#                       {'relationship = Unmarried': ['<=50K',
#                         {'race = Other': ['>50K',
#                           {'fnlwgt <= 220640': [{'fnlwgt <= 137527': [{'fnlwgt <= 22494': ['>50K',
#                                 {'workclass = Self-emp-inc': ['>50K',
#                                   {'occupation = Sales': [{'age <= 38': ['>50K',
#                                       '<=50K']},
#                                     '<=50K']}]}]},
#                               {'occupation = Prof-specialty': [{'fnlwgt <= 188503': [{'fnlwgt <= 187098': ['<=50K',
#                                     '>50K']},
#                                   '<=50K']},
#                                 '<=50K']}]},
#                             '<=50K']}]}]}]}]},
#                   '<=50K']}]}]},
#             {'age <= 32': [{'fnlwgt <= 196025': ['<=50K',
#                 {'hours_per_week <= 50': ['>50K', '<=50K']}]},
#               {'capital_loss <= 0': [{'race = White': [{'relationship = Other-relative': ['<=50K',
#                     {'fnlwgt <= 37314': ['<=50K',
#                       {'occupation = Farming-fishing': ['<=50K',
#                         {'age <= 58': ['>50K', '<=50K']}]}]}]},
#                   '>50K']},
#                 '>50K']}]}]}]}]}]},
#     '>50K']}]}

# %%
count_nodes(pruned_tree)
# Out:
# 1135

# %%
count_depth(pruned_tree)
# Out:
# 82

# %%
def acc_on_sets(tree,train_df,test_df):
    accuracy_train = calculate_accuracy(train_df,tree)
    accuracy_test = calculate_accuracy(test_df,tree)

    print("Training Set Accuracy:",accuracy_train)
    print("Test Set Accuracy:",accuracy_test)

# %%
acc_on_sets(tree , df_train, df_test)#combined tree
# Out:
# Training Set Accuracy: 0.9782728272827282
# Test Set Accuracy: 0.8184017868221863

# %%
acc_on_sets(pruned_tree,df_train,df_test)
# Out:
# Training Set Accuracy: 0.8891639163916392
# Test Set Accuracy: 0.8728750465318278
